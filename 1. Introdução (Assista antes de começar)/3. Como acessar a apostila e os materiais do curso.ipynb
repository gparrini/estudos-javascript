# %%
import os
import re
import shutil

def organizar_por_nome_de_aula():
    diretorio_atual = os.getcwd()
    arquivo_txt = os.path.join(diretorio_atual, "00_MAPA_DE_RENOMEACAO.txt")

    if not os.path.exists(arquivo_txt):
        print("❌ Erro: O arquivo '00_MAPA_DE_RENOMEACAO.txt' não foi encontrado nesta pasta.")
        return

    def limpar_nome_sistema(nome):
        return re.sub(r'[\\/*?:"<>|]', "", nome).strip()

    regras = []
    with open(arquivo_txt, "r", encoding="utf-8") as f:
        for linha in f:
            match = re.search(r'\[Arquivo \d+\] -> (.*?)\s*\|\|\s*(.*?)\s*\|\|\s*(.*)', linha)
            if match:
                modulo = limpar_nome_sistema(match.group(1))
                submodulo = limpar_nome_sistema(match.group(2))
                nome_aula = limpar_nome_sistema(match.group(3))
                regras.append((modulo, submodulo, nome_aula))

    if not regras:
        print("❌ O arquivo de texto não possui dados válidos mapeados.")
        return

    # Lista apenas arquivos (ignora pastas ocultas que o Jupyter cria, como .ipynb_checkpoints)
    todos_arquivos = [f for f in os.listdir(diretorio_atual) if os.path.isfile(os.path.join(diretorio_atual, f))]
    
    # Ignora o txt do mapa e o próprio notebook
    arquivos_downloads = [
        f for f in todos_arquivos 
        if f not in ("00_MAPA_DE_RENOMEACAO.txt", "organizador.ipynb")
    ]
    
    arquivos_downloads.sort(key=lambda x: os.path.getmtime(os.path.join(diretorio_atual, x)))

    if not arquivos_downloads:
        print("❌ Nenhum arquivo baixado encontrado para organizar.")
        return

    print(f"📦 Movendo e organizando {len(arquivos_downloads)} arquivos nas pastas...\n")

    for i, (modulo, submodulo, nome_aula) in enumerate(regras):
        if i >= len(arquivos_downloads):
            break

        nome_original = arquivos_downloads[i]
        caminho_original = os.path.join(diretorio_atual, nome_original)
        _, extensao = os.path.splitext(nome_original)

        pasta_destino = os.path.join(diretorio_atual, modulo, submodulo)
        os.makedirs(pasta_destino, exist_ok=True)

        novo_nome = f"{nome_aula}{extensao}"
        caminho_destino = os.path.join(pasta_destino, novo_nome)

        contador_duplicado = 1
        while os.path.exists(caminho_destino):
            novo_nome = f"{nome_aula}_({contador_duplicado}){extensao}"
            caminho_destino = os.path.join(pasta_destino, novo_nome)
            contador_duplicado += 1

        try:
            shutil.move(caminho_original, caminho_destino)
            print(f"✅ {modulo} \\ {submodulo} \\ {novo_nome}")
        except Exception as e:
            print(f"❌ Falha ao mover {nome_original}: {e}")

    print("\n🎉 Estrutura de pastas criada com perfeição! Tudo limpo e organizado.")

# No Jupyter, você pode simplesmente chamar a função assim:
organizar_por_nome_de_aula()
# Out:
# 📦 Movendo e organizando 65 arquivos nas pastas...
#
# ✅ Módulo Sem Nome \ 1. Introdução (Assista antes de começar) \ 3. Como acessar a apostila e os materiais do curso.ipynb
# ✅ Módulo Sem Nome \ 3. Introdução ao HTML \ 1. O que é o HTML.zip
# ✅ Módulo Sem Nome \ 3. Introdução ao HTML \ 10. Desafio 1 - Apresentando o Desafio.zip
# ✅ Módulo Sem Nome \ 3. Introdução ao HTML \ 11. Desafio 1 - Construindo o Desafio do Zero - Parte 1.zip
# ✅ Módulo Sem Nome \ 3. Introdução ao HTML \ 14. Desafio 2 - Home da Hashtag Treinamentos.zip
# ✅ Módulo Sem Nome \ 3. Introdução ao HTML \ 15. Desafio 2 - Criando o Cabeçalho - Parte 1.pdf
# ✅ Módulo Sem Nome \ 3. Introdução ao HTML \ 20. Desafio 2 - Criando a Seção Diferenciais.zip
# ✅ Módulo Sem Nome \ 4. Introdução ao CSS \ 1. O que é CSS.txt
# ✅ Módulo Sem Nome \ 4. Introdução ao CSS \ 10. Desafio 1 - Formatando uma página em HTML.zip
# ✅ Módulo Sem Nome \ 4. Introdução ao CSS \ 11. Desafio 1 - Resolvendo o Desafio.zip
# ✅ Módulo Sem Nome \ 4. Introdução ao CSS \ 12. Desafio 2 - Formatando a Home da Hashtag.zip
# ✅ Módulo Sem Nome \ 4. Introdução ao CSS \ 13. Desafio 2 - Formatando o Cabeçalho - Parte 1.zip
# ✅ Módulo Sem Nome \ 5. Aprofundando no HTML \ 1. Apresentação do Módulo.zip
# ✅ Módulo Sem Nome \ 5. Aprofundando no HTML \ 11. selectedcontent.zip
# ✅ Módulo Sem Nome \ 5. Aprofundando no HTML \ 12. Desafio 1 - Apresentando o Desafio.zip
# ✅ Módulo Sem Nome \ 5. Aprofundando no HTML \ 13. Desafio 1 - Construindo juntos - Parte 1.zip
# ✅ Módulo Sem Nome \ 5. Aprofundando no HTML \ 16. Desafio 2 - Explicando as novidades.zip
# ✅ Módulo Sem Nome \ 5. Aprofundando no HTML \ 17. Desafio 2 - Completando o Cabeçalho.zip
# ✅ Módulo Sem Nome \ 6. Aprofundando no CSS \ 1. Apresentação do Módulo.zip
# ✅ Módulo Sem Nome \ 6. Aprofundando no CSS \ 18. Desafio 1 - Evoluindo a página de Exercício.zip
# ✅ Módulo Sem Nome \ 6. Aprofundando no CSS \ 19. Desafio 1 - Gabarito - Parte 1.zip
# ✅ Módulo Sem Nome \ 6. Aprofundando no CSS \ 22. Desafio 2 - Aprofundando no Desafio 2.zip
# ✅ Módulo Sem Nome \ 6. Aprofundando no CSS \ 23. Desafio 2 - Aprofundando o Cabeçalho - Parte 1.zip
# ✅ Módulo Sem Nome \ 6. Aprofundando no CSS \ 24. Desafio 2 - Aprofundando o Cabeçalho - Parte 2.zip
# ✅ Módulo Sem Nome \ 6. Aprofundando no CSS \ 25. Desafio 2 - Aprofundando o Cabeçalho - Parte 3.zip
# ✅ Módulo Sem Nome \ 7. Flexbox no CSS \ 1. Apresentação do Módulo.zip
# ✅ Módulo Sem Nome \ 7. Flexbox no CSS \ 7. Desafio 1 - Construindo Layouts com Flexbox.zip
# ✅ Módulo Sem Nome \ 7. Flexbox no CSS \ 8. Desafio 1 - Gabarito.zip
# ✅ Módulo Sem Nome \ 7. Flexbox no CSS \ 9. Desafio 2 - Flexbox na Home da Hashtag.zip
# ✅ Módulo Sem Nome \ 7. Flexbox no CSS \ 10. Desafio 2 - Flexbox no Cabeçalho.zip
# ✅ Módulo Sem Nome \ 8. Componentes Personalizados no HTML \ 1. Apresentação do Módulo.zip
# ✅ Módulo Sem Nome \ 8. Componentes Personalizados no HTML \ 3. Paginação - Resolução 12.zip
# ✅ Módulo Sem Nome \ 8. Componentes Personalizados no HTML \ 6. Acordeão - Resolução.zip
# ✅ Módulo Sem Nome \ 8. Componentes Personalizados no HTML \ 8. Popup - Resolução.zip
# ✅ Módulo Sem Nome \ 8. Componentes Personalizados no HTML \ 10. Carrossel - Resolução 12.zip
# ✅ Módulo Sem Nome \ 8. Componentes Personalizados no HTML \ 12. Desafio 2 - Criando o Popup da Home da Hashtag.zip
# ✅ Módulo Sem Nome \ 8. Componentes Personalizados no HTML \ 13. Desafio 2 - Gabarito.zip
# ✅ Módulo Sem Nome \ 9. Grid no CSS \ 1. Apresentação do Módulo.zip
# ✅ Módulo Sem Nome \ 9. Grid no CSS \ 13. Desafio 1 - Construindo um layout com Grid.zip
# ✅ Módulo Sem Nome \ 9. Grid no CSS \ 14. Desafio 1 - Gabarito.zip
# ✅ Módulo Sem Nome \ 9. Grid no CSS \ 15. Desafio 2 - Usando Grid na Seção Blog.zip
# ✅ Módulo Sem Nome \ 9. Grid no CSS \ 16. Desafio 2 - Gabarito.zip
# ✅ Módulo Sem Nome \ 11. Animações e Efeitos no CSS \ 1. Apresentação do Módulo.zip
# ✅ Módulo Sem Nome \ 11. Animações e Efeitos no CSS \ 9. Desafio 1 - Criando um Elementos Animado.zip
# ✅ Módulo Sem Nome \ 11. Animações e Efeitos no CSS \ 10. Desafio 1 - Gabarito.zip
# ✅ Módulo Sem Nome \ 11. Animações e Efeitos no CSS \ 11. Desafio 2 - Transições na Home da Hashtag.zip
# ✅ Módulo Sem Nome \ 11. Animações e Efeitos no CSS \ 12. Desafio 2 - Gabarito.zip
# ✅ Módulo Sem Nome \ 12. Responsividade e Otimizações \ 1. Apresentação do Módulo.zip
# ✅ Módulo Sem Nome \ 12. Responsividade e Otimizações \ 16. Desafio 2 - Deixando a Home da Hashtag responsiva.zip
# ✅ Módulo Sem Nome \ 12. Responsividade e Otimizações \ 17. Desafio 2 - Criando a primeira Media Query.zip
# ✅ Módulo Sem Nome \ 13. Float no CSS \ 1. Apresentação do Módulo.zip
# ✅ Módulo Sem Nome \ 13. Float no CSS \ 3. Desafio - Construindo um layout com float.zip
# ✅ Módulo Sem Nome \ 13. Float no CSS \ 4. Desafio - Gabarito.zip
# ✅ Módulo Sem Nome \ 14. Metodologia BEM \ 1. Apresentação do Módulo.zip
# ✅ Módulo Sem Nome \ 14. Metodologia BEM \ 6. Exemplo prático.zip
# ✅ Módulo Sem Nome \ 14. Metodologia BEM \ 7. Desafio - Apresentação.zip
# ✅ Módulo Sem Nome \ 14. Metodologia BEM \ 8. Desafio - Gabarito.zip
# ✅ Módulo Sem Nome \ 15. Extensão - SASS \ 1. Apresentação do Módulo.zip
# ✅ Módulo Sem Nome \ 16. Projeto de Página de Captura (SASS) \ 2. Configurando o nosso projeto.zip
# ✅ Módulo Sem Nome \ 17. Projeto de E-commerce (SASS) \ 2. Configurações iniciais.zip
# ✅ Módulo Sem Nome \ 18. Framework - Bootstrap \ 1. Apresentação do Módulo.zip
# ✅ Módulo Sem Nome \ 19. Projeto de Landing Page (Bootstrap) \ 1. Apresentação do Desafio.zip
# ✅ Módulo Sem Nome \ 21. Framework - Tailwind CSS \ 1. Apresentação do Módulo e do Tailwind.zip
# ✅ Módulo Sem Nome \ 22. Projeto de Página Minimalista (Tailwind) \ 1. Apresentando o Desafio.zip
#
# 🎉 Estrutura de pastas criada com perfeição! Tudo limpo e organizado.
